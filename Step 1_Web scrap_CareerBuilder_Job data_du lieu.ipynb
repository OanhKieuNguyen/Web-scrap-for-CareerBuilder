# %%
import pandas as pd

# %%
import re
import time

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
def get_soup(url, load_sleep_time, scroll_sleep_time):

    # Set up the driver to use a headless Chrome browser
    options = webdriver.ChromeOptions()
    options.add_argument('headless')
    driver = webdriver.Chrome(options=options)

    # Load the URL in the browser and wait for the page to load
    driver.get(url)
    driver.implicitly_wait(load_sleep_time)

    # Scroll down the page to load more jobs (repeat this several times)
    for i in range(5):
        driver.execute_script(
            "window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(scroll_sleep_time)

    # Extract the HTML content from the fully rendered page
    html_content = driver.page_source
    driver.quit()

    # Parse the HTML content (of the searching_page) using BeautifulSoup
    html_content = BeautifulSoup(html_content, 'html.parser')

    return html_content

# %%
def get_search_soups(key_word, category_code, page_num, load_sleep_time, scroll_sleep_time):
    """_summary_
    Get the html_soup of the job_searching_page for a specific key_word. 
    Automatically jump through all pages if the result of the searching keyword spread on multiple pages. 

    Args:
        key_word (_type_): key_word for searching jobs on the website
        category_code (_type_): this is just 1 part of the url structure when you search jobs on CareerBuilder. You should look at the source code, look at the search_url below, then then look at a real job_searching_url you'll understand.
        page_num (_type_): number of pages the key_word return on the web
        load_sleep_time (_type_): time to wait for the page to fully load its content
        scroll_sleep_time (_type_): time to wait after each scrolling down. (because some page does not automaticall load all of it's content, unless you scroll down)

    Returns:
        _bs4.BeautifulSoup_: this returns a list of html_soup of all the searching pages 
    """
    print(
        f'scrapping {page_num} searching_pages of {key_word} on CareerBuilder', flush=True)

    search_soups = []  # create an empty string to store all the infomation
    # looping through pages & getting the html soup
    for i in range(1, page_num + 1):
        search_url = f'https://careerbuilder.vn/viec-lam/{key_word}-{category_code}-trang-{i}-vi.html'

        # Get & Parse the HTML content (of the searching_page)
        search_soup = get_soup(url=search_url,
                               load_sleep_time=load_sleep_time,
                               scroll_sleep_time=scroll_sleep_time)
        search_soups.append(search_soup)

    # Print out number of currently available jobs for the searching key_word
    # `flush=True` is for printing jobs even if we are in a function.
    print(
        f"Total: {search_soups[0].find('div', class_ = 'job-found-amout').text}", flush=True)
    return search_soups

# %%
def extract_search_page(search_soups):
    """_summary_
    Extract information from the search_pages

    Returns:
        _pd.DataFrame_: return a df contains: 'job_link', 'job_title', 'comp_name', 'salary', 'location', 'welfare', 'expire_date', 'update_date'
    """
    support_list = []   # store data for 1 page
    for soup in search_soups:
        job_titles = soup.find_all('a', class_='job_link')
        infos = soup.find_all('div', class_='caption')
        update_dates = soup.find_all('div', class_='bottom-right-icon')
        for i, job_title in enumerate(job_titles):
            if i % 2 == 0:  # this is bc, there is a duplicate value for each `<a class="job_link"`
                # Extract job title, job_link
                job_title_text = job_title.text.strip()
                job_link = job_title.get('href')

                # Extract other job details from corresponding all_infos element (using the index `i`)
                info = infos[i//2]
                comp_name = info.find('a', class_='company-name').text.strip()
                salary = info.find('div', class_='salary').text.strip()
                expire_date = info.find(
                    'div', class_='expire-date').text.strip()

                # Extract the update_date from update_dates (using the index `i`)
                update_date = update_dates[i//2]
                update_date = re.findall('\d{2}-\d{2}-\d{4}', update_date.text)

                # All the welfares & locations are bundled together, so we have to extract them differently:
                welfares_tag = info.find('ul', class_='welfare')
                welfare = ''
                # to check if the ('ul', class_='welfare') exist
                if welfares_tag:
                    for li in welfares_tag.find_all('li'):
                        # concat text in each li tag seperated by ', '
                        welfare += li.get_text(strip=True) + ', '
                    # getting rid of the redundant ', ' at the end
                    welfare = welfare[:-2]

                locations_tag = info.find('div', class_='location')
                location = ''
                if locations_tag:
                    for li in locations_tag.find_all('li'):
                        # concat text in each li tag seperated by ', '
                        location += li.get_text(strip=True) + ', '
                    # getting rid of the redundant ', ' at the end
                    location = location[:-2]

                # Create a dictionary to store the scraped data including the job_title
                job_dict = {
                    'job_link': job_link,
                    'job_title': job_title_text,
                    'comp_name': comp_name,
                    'salary': salary,
                    'location': location,
                    'welfare': welfare,
                    'expire_date': expire_date,
                    'update_date': update_date
                }

                # Append the job dictionary to the list of jobs & then convert to dataframe
                support_list.append(job_dict)

    df_search_page = pd.DataFrame(support_list)
    return df_search_page

# %%
# options for extract job_link w different html structure
def support_extract_job_link1(job_url, load_sleep_time, scroll_sleep_time):
    """_summary_
    Attempt 1 of getting the infos from the job_url
    """
    # Extract & Parse the HTML content using BeautifulSoup
    # job_url="https://careerbuilder.vn/vi/tim-viec-lam/data-analyst.35BD61DD.html"
    detail_soup = get_soup(url=job_url,
                           load_sleep_time=load_sleep_time,
                           scroll_sleep_time=scroll_sleep_time)

    # get the section & its children
    job_detail_content_soup = detail_soup.find(
        'section', class_='job-detail-content')
    job_desc_soup = job_detail_content_soup.find(
        'div', class_='detail-row reset-bullet')

    support_dict = {}
    # bg_blue_soup
    bg_blue_soup = job_detail_content_soup.find('div', class_='bg-blue')
    for i in bg_blue_soup.find_all('strong'):
        support_dict.update({
            i.text.strip():
                i.next_sibling.next_sibling.text.strip()
        })

    # # welfares
    # welfares_soup = job_detail_content_soup.find('div', class_='detail-row')
    # welfares_text = welfares_soup.text.strip().split(sep='\n')
    # welfares_text = [x for x in welfares_text if x != ""]
    # support_dict.update({
    #     "benefits":
    #         str(welfares_text[1:])
    # })

    # # job_desc
    # job_desc_text = job_desc_soup.text.strip()
    # support_dict.update({"job_desc": job_desc_text})

    # # job_tags, notice that, some jobs do not have job_tags
    # job_tag_soup = job_detail_content_soup.find('div', class_='job-tags')
    # if job_tag_soup == None:
    #     job_tag_text = None
    # else:
    #     # jobs-do-not-have-job-tags would make this result in errors
    #     job_tag_text = job_tag_soup.text.strip().split(sep='\n')
    #     job_tag_text = str([x for x in job_tag_text if x != ""][1:])
    # support_dict.update({
    #     "job_tags":
    #         str(job_tag_text)
    # })

    return support_dict

# %%
def support_extract_job_link2(job_url, load_sleep_time, scroll_sleep_time):
    """_summary_
    Attempt 2 of getting the infos from the job_url
    """
    detail_soup = get_soup(url=job_url,
                           load_sleep_time=load_sleep_time,
                           scroll_sleep_time=scroll_sleep_time)

    # Extracting information:
    support_dict = {}

    # [ 'Địa điểm', 'Ngày cập nhật', 'Ngành nghề', 'Hình thức', 'Lương', 'Kinh nghiệm', 'Cấp bậc', 'Hết hạn nộp']
    box_infos_soup = detail_soup.find_all('div', class_='box-info')
    for info in box_infos_soup:
        td_names = info.find_all('td', class_='name')
        for i in td_names[:7]:
            support_dict.update({i.text.strip():
                                i.find_next_sibling().text.strip()})

    # # Extracting benefits
    # welfares_soup = detail_soup.find('div', class_='detail-row box-welfares')
    # welfares_text = welfares_soup.text.strip().split(sep='\n')  # .replace('\n', ',')
    # welfares_text = str([x for x in welfares_text if x != ""][1:])
    # support_dict.update({'benefits': welfares_text})

    # # Extracting job_desc: so to make things simple. I'll store all the infor of JD in just 1 column
    # job_desc_soup = detail_soup.find('div', class_='full-content')
    # job_desc_text = job_desc_soup.text.strip().replace("\n\n", "\n")
    # support_dict.update({'job_desc': job_desc_text})
    # # support_df = pd.DataFrame(support_dict, index=[0])

    # # job_tags, notice that some jobs-do-not-have-job-tags
    # job_tag_soup = detail_soup.find('div', class_='job-tags detail-row')
    # if job_tag_soup == None:
    #     job_tag_text = None
    # else:
    #     # jobs-do-not-have-job-tags would make this result in errors
    #     job_tag_text = job_tag_soup.text.strip().split(sep='\n')
    #     job_tag_text = str([x for x in job_tag_text if x != ""][1:])
    # support_dict.update({
    #     "job_tags":
    #         str(job_tag_text)
    # })

    return support_dict

# %%
def support_extract_job_link3(job_url, load_sleep_time, scroll_sleep_time):
    # job_url="https://careerbuilder.vn/vi/tim-viec-lam/giam-doc-xuat-nhap-khau.35BDBFFA.html"
    detail_soup = get_soup(
        url=job_url, load_sleep_time=load_sleep_time, scroll_sleep_time=scroll_sleep_time)

    # Extracting information:
    support_dict = {}

    # [ 'Địa điểm', 'Ngày cập nhật', 'Ngành nghề', 'Hình thức', 'Lương', 'Kinh nghiệm', 'Cấp bậc', 'Hết hạn nộp']
    box_infos_soup = detail_soup.find(
        'div', class_='boxtp info-career', id="info-career-desktop")
    li_tags = box_infos_soup.find_all('li')
    for li in li_tags:
        text = li.text.split("\n")
        key = text[0].strip()
        content = text[1].strip()
        support_dict.update({key: content})

    # Other infos, I will update later.

    return support_dict

# %%
def support_extract_job_link4(job_url, load_sleep_time, scroll_sleep_time):
    # job_url="https://careerbuilder.vn/vi/tim-viec-lam/chuyen-vien-kinh-doanh-forwarding.35BDA00A.html"
    detail_soup = get_soup(
        url=job_url, load_sleep_time=load_sleep_time, scroll_sleep_time=scroll_sleep_time)

    # Extracting information:
    support_dict = {}

    # [ 'Địa điểm', 'Ngày cập nhật', 'Ngành nghề', 'Hình thức', 'Lương', 'Kinh nghiệm', 'Cấp bậc', 'Hết hạn nộp']
    box_infos_soup = detail_soup.find(
        'div', class_='DetailJobNew', id="info-career-mb")
    # print(box_infos_soup.prettify())
    li_tags = box_infos_soup.find_all('li')
    # li_tags[7].text
    for li in li_tags[:7]:
        text = li.text.split("\n")
        key = text[1].strip()
        content = text[2].strip()
        support_dict.update({key: content})

    # Other infos, I will update later.

    return support_dict

# %%
def extract_job_links(df_search_page, load_sleep_time, scroll_sleep_time):
    """_summary_
    Getting infomation from the job_links. Returns a pd.DataFrame
    """
    failed_dict = {'Địa điểm': 'failed',
                   'Ngày cập nhật': 'failed',
                   'Ngành nghề': 'failed',
                   'Hình thức': 'failed',
                   'Lương': 'failed',
                   'Kinh nghiệm': 'failed',
                   'Cấp bậc': 'failed',
                   'Hết hạn nộp': 'failed',
                   'benefits': 'failed',
                   'job_desc': 'failed',
                   'job_tag': 'failed',
                   'benefit': 'failed'
                   }
    # UX/UI: getting the number of jobs processing & progression.
    num_jobs = df_search_page.job_link.shape[0]
    failed_indices = {}  # for storing failed job_link
    list_support_dict = []
    stt = 0
    for job_url in df_search_page.job_link:
        # print(job_url)
        stt += 1
        print(stt, '/', num_jobs, 'jobs scraped')
        try:
            support_dict1 = support_extract_job_link1(job_url=job_url,
                                                      load_sleep_time=load_sleep_time,
                                                      scroll_sleep_time=scroll_sleep_time)
            list_support_dict.append(support_dict1)
        except Exception as e:
            print(f"First attempt failed for {job_url}: {e}")
            try:
                support_dict = support_extract_job_link2(job_url=job_url,
                                                         load_sleep_time=load_sleep_time,
                                                         scroll_sleep_time=scroll_sleep_time)
                list_support_dict.append(support_dict)
                print("Second attempt succeed")
            except Exception as e:
                print(f"Second attempt failed for {job_url}: {e}")
                try:
                    support_dict = support_extract_job_link3(job_url=job_url,
                                                             load_sleep_time=load_sleep_time,
                                                             scroll_sleep_time=scroll_sleep_time)
                    list_support_dict.append(support_dict)
                    print("Third attempt succeed")
                except Exception as e:
                    print(f"Third attempt failed for {job_url}: {e}")
                    try:
                        support_dict = support_extract_job_link4(job_url=job_url,
                                                                 load_sleep_time=load_sleep_time,
                                                                 scroll_sleep_time=scroll_sleep_time)
                        list_support_dict.append(support_dict)
                        print("4th attempt succeed")
                    except Exception as e:
                        print(f"4th attempt failed for {job_url}: {e}")
                # only job that fail twice will be concatenated
                failed_indices.update({stt: job_url})
                list_support_dict.append(failed_dict)
                continue

    # create the df_job_link that stores infos from the job_link page
    df_job_link = pd.DataFrame()
    for i in list_support_dict:
        i_df = pd.DataFrame(data=i, index=[0])
        # axis=0 to concat vertically.
        df_job_link = pd.concat([df_job_link, i_df],
                                axis=0).reset_index(drop=True)

    # UI/UX: do some printing jobs to inform users about the process of executing the function.
    print(f'success {num_jobs - len(failed_indices)} out of {num_jobs} jobs\
        ({100 - round(len(failed_indices) * 100 / num_jobs, 2)}%)', flush=True)
    print(f'failed {len(failed_indices)} out of {num_jobs} jobs\
        ({round(len(failed_indices) * 100 / num_jobs, 2)}%)', flush=True)
    print("Failed Indices:", failed_indices)

    # cleaning detail_df
    rename_dict = {
        'Địa điểm': 'location',
        'Ngày cập nhật': 'update_date',
        'Ngành nghề': 'industry',
        'Hình thức': 'staff_type',
        'Lương': 'salary',
        'Kinh nghiệm': 'exp',
        'Cấp bậc': 'job_level',
        'Hết hạn nộp': 'expire_date'
    }
    df_job_link.columns = df_job_link.columns.str.strip()
    df_job_link = df_job_link.rename(columns=rename_dict)
    cols_for_editing = df_job_link.columns[df_job_link.columns != 'job_desc']
    df_job_link[cols_for_editing] = df_job_link[cols_for_editing].applymap(
        lambda x: str(x)
        .replace("['", "").replace("']", "")
        .replace('  ', '')
        .replace("'", "")
        .replace('\n', '')
        .replace('\t', '')
        .replace('\\n', '')
        .replace('\\t', '').strip()
    )
    return df_job_link

# %%
def merge_search_page_n_job_link(df_search_page, df_job_link):
    return df_search_page.merge(df_job_link, left_index=True, right_index=True)


# -----------------------------------//-----------------------------------
# testing the function on https://careerbuilder.vn/viec-lam/Data-Analyst-k-vi.html

# soup=get_soup(url="https://careerbuilder.vn/vi/tim-viec-lam/sales-logistics.35BDC14E.html",
#               load_sleep_time=5,
#               scroll_sleep_time=1)
# print(soup.text)


# search_soups = get_search_soups(key_word='data-analyst',
#                                 category_code='k',
#                                 page_num=2,
#                                 load_sleep_time=10,
#                                 scroll_sleep_time=1)
# type(search_soups[0])  # this has to be bs4.Beautifulsoup
# search_soups

# #
# df_search_page = extract_search_page(
#     search_soups=search_soups)  # this looks good
# df_search_page = df_search_page[:10].reset_index(
#     drop=True)  # reduce the df for testing

# #
# # job_url = "https://careerbuilder.vn/vi/tim-viec-lam/data-analyst.35BD57F7.html"
# # sup_dict = support_extract_job_link2(job_url=job_url)
# # pd.DataFrame(sup_dict, index=['test'])


# df_job_link = extract_job_links(df_search_page=df_search_page)
# df_job_link

# #
# merge_search_page_n_job_link(df_search_page=df_search_page,
#                              df_job_link=df_job_link) # this looks beautiful


# job_url="https://careerbuilder.vn/vi/tim-viec-lam/giam-doc-xuat-nhap-khau.35BDBFFA.html"
# support_extract_job_link3(job_url=job_url, load_sleep_time=10, scroll_sleep_time=1)


# job_url = "https://careerbuilder.vn/vi/tim-viec-lam/chuyen-vien-kinh-doanh-forwarding.35BDA00A.html"
# support_extract_job_link4(
#     job_url=job_url, load_sleep_time=10, scroll_sleep_time=1)

# %%
# get search_soup
search_soups = get_search_soups(
    key_word='du-lieu',
    category_code='k',
    page_num=10,
    load_sleep_time=10,
    scroll_sleep_time=1
)
# Out:
# scrapping 10 searching_pages of du-lieu on CareerBuilder
# Total:
# 2206 việc làm  du lieu

# %%
import selenium
selenium.__version__
# Out:
# '4.9.0'

# %%
# Parsing data from the search_pages
df_search_page = extract_search_page(search_soups=search_soups)

# %%
df_search_page
# Out:
#                                               job_link  \
# 0    https://careerbuilder.vn/vi/tim-viec-lam/kien-...
# 1    https://careerbuilder.vn/vi/tim-viec-lam/kien-...
# 2    https://careerbuilder.vn/vi/tim-viec-lam/data-...
# 3    https://careerbuilder.vn/vi/tim-viec-lam/busin...
# 4    https://careerbuilder.vn/vi/tim-viec-lam/busin...
# ..                                                 ...
# 495  https://careerbuilder.vn/vi/tim-viec-lam/brand...
# 496  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 497  https://careerbuilder.vn/vi/tim-viec-lam/lap-t...
# 498  https://careerbuilder.vn/vi/tim-viec-lam/ky-th...
# 499  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
#
#                                              job_title  \
# 0                                    Kiến trúc Dữ liệu
# 1                                    Kiến trúc Dữ liệu
# 2                         Data Engineer - Khối Dữ liệu
# 3                      Business Analyst - Khối Dữ Liệu
# 4                      Business Analyst - Khối Dữ Liệu
# ..                                                 ...
# 495                                      Brand Manager
# 496                                  NHÂN VIÊN KẾ TOÁN
# 497                 Lập trình viên Full Stack - Hà Nội
# 498                           Kỹ thuật viên xét nghiệm
# 499  Chuyên viên cao cấp - Kế Hoạch Hàng Hóa (Merch...
#
#                                       comp_name                    salary  \
# 0       Ngân Hàng TMCP Sài Gòn - Hà Nội ( SHB )         Lương: Cạnh tranh
# 1       Ngân Hàng TMCP Sài Gòn - Hà Nội ( SHB )         Lương: Cạnh tranh
# 2                       Ngân Hàng TMCP Quân Đội         Lương: Cạnh tranh
# 3                       Ngân Hàng TMCP Quân Đội         Lương: Cạnh tranh
# 4                       Ngân Hàng TMCP Quân Đội         Lương: Cạnh tranh
# ..                                          ...                       ...
# 495         Công Ty Cổ Phần Đầu Tư K&G Việt Nam  Lương: 30 Tr - 40 Tr VND
# 496         Công ty Cổ Phần Tập đoàn Madi Group   Lương: 8 Tr - 15 Tr VND
# 497                       Công ty cổ phần SANAN  Lương: 15 Tr - 20 Tr VND
# 498                           Tập Đoàn Y Tế AMV   Lương: 7 Tr - 12 Tr VND
# 499  Công Ty CP Vàng Bạc Đá Quý Phú Nhuận - PNJ         Lương: Cạnh Tranh
#
#         location                                  welfare  \
# 0         Hà Nội         Laptop, Chế độ bảo hiểm, Du Lịch
# 1         Hà Nội         Laptop, Chế độ bảo hiểm, Du Lịch
# 2         Hà Nội  Chế độ bảo hiểm, Du Lịch, Chế độ thưởng
# 3         Hà Nội
# 4         Hà Nội  Chế độ bảo hiểm, Du Lịch, Chế độ thưởng
# ..           ...                                      ...
# 495       Hà Nội  Chế độ bảo hiểm, Du Lịch, Chế độ thưởng
# 496       Hà Nội  Chế độ bảo hiểm, Du Lịch, Chế độ thưởng
# 497       Hà Nội         Laptop, Chế độ bảo hiểm, Du Lịch
# 498  Hồ Chí Minh  Chế độ bảo hiểm, Du Lịch, Chế độ thưởng
# 499  Hồ Chí Minh         Laptop, Chế độ bảo hiểm, Phụ cấp
#
#                           expire_date   update_date
# 0                 Hạn nộp: 26-12-2023  [27-11-2023]
# 1                 Hạn nộp: 24-12-2023  [25-11-2023]
# 2                 Hạn nộp: 31-12-2023  [01-12-2023]
# 3    Cơ hội ứng tuyển chỉ còn: 3 ngày  [07-11-2023]
# 4                 Hạn nộp: 10-12-2023  [11-11-2023]
# ..                                ...           ...
# 495                                    [20-11-2023]
# 496               Hạn nộp: 25-12-2023  [26-11-2023]
# 497               Hạn nộp: 26-12-2023  [27-11-2023]
# 498               Hạn nộp: 31-12-2023  [27-11-2023]
# 499               Hạn nộp: 25-12-2023  [28-11-2023]
#
# [500 rows x 8 columns]

# %%
"""
for index, title in enumerate(df_search_page.job_title.tolist()): 
    print(index, title)
# after printing out the job-titles, i see that 200 is kinda the sweet spot for relevance, 
# all the jobs after the 4th page does not seem relevant to the keyword anymore. 
"""
for index, title in enumerate(df_search_page.job_title.tolist()): 
    print(index, title)
# Out:
# 0 Kiến trúc Dữ liệu
# 1 Kiến trúc Dữ liệu
# 2 Data Engineer - Khối Dữ liệu
# 3 Business Analyst - Khối Dữ Liệu
# 4 Business Analyst - Khối Dữ Liệu
# 5 Chuyên Viên Phân Tích Dữ Liệu
# 6 Chuyên gia Phân tích dữ liệu - CVP
# 7 Chuyên gia Phân tích dữ liệu
# 8 Kỹ Sư Dữ Liệu
# 9 Chuyên Viên Dữ Liệu
# 10 Chuyên viên/CVCC/Chuyên gia Quản lý cấu trúc dữ liệu - Khối Dữ liệu
# 11 Chuyên viên/CVCC/Chuyên gia Chính sách và chất lượng dữ liệu - Khối Dữ liệu
# 12 Văn phòng Chuyển đổi - Trung tâm Dữ liệu & Phân tích - Trưởng Phòng Quản trị dữ liệu
# 13 Văn phòng Chuyển đổi - Trung tâm Dữ liệu & Phân tích - Chuyên gia Quản trị dữ liệu
# 14 Data Scientist - Trung tâm Công nghệ Dữ Liệu - Khối Dữ Liệu
# 15 Data Scientist - Trung tâm Công nghệ Dữ Liệu - Khối Dữ Liệu
# 16 Data Analyst - Khối Dữ Liệu
# 17 Chuyên viên Quản lý Kho và Mô hình dữ liệu
# 18 Chuyên viên Quản lý Kho và Mô hình dữ liệu
# 19 Chuyên viên Phân tích Dữ liệu (Khối CNTT)
# 20 Chuyên viên Phân tích Dữ liệu (Khối CNTT)
# 21 Chuyên viên Phân tích Dữ liệu (Khối CNTT)
# 22 Giám đốc Trung tâm Nền tảng dữ liệu
# 23 Chuyên viên cao cấp (Data Architect) - Khối Dữ Liệu
# 24 Chuyên viên tích hợp dữ liệu (Intergration Engineering)
# 25 Chuyên viên tích hợp dữ liệu (Intergration Engineering)
# 26 Chuyên viên tích hợp dữ liệu (Intergration Engineering)
# 27 CVCC/CG Kiến trúc dữ liệu - Ban Dự án
# 28 CVCC/CG Kiến trúc dữ liệu - Ban Dự án
# 29 Chuyên viên Quản trị cơ sở dữ liệu (Database Administrator)
# 30 Chuyên viên cao cấp Phân tích dữ liệu rủi ro
# 31 Chuyên viên cao cấp Phân tích dữ liệu rủi ro
# 32 Chuyên Viên - Quản Trị Mô Hình Dữ Liệu (Data Modeling)
# 33 Chuyên Viên - Quản Trị Mô Hình Dữ Liệu (Data Modeling)
# 34 Văn phòng Chuyển đổi - Trung tâm Dữ liệu & Phân tích - Chuyên gia Phòng Chiến lược dữ liệu
# 35 Văn phòng Chuyển đổi - Trung tâm Dữ liệu & Phân tích - Tổ trưởng Phòng Phân tích & Khai thác Dữ liệu
# 36 Văn phòng Chuyển đổi - Trung tâm Dữ liệu & Phân tích - Chuyên gia Phòng Phân tích & Khai thác Dữ liệu
# 37 Chuyên viên Phân tích dữ liệu
# 38 Chuyên viên Tài chính mảng Dữ liệu
# 39 Văn phòng Chuyển đổi - Trung tâm Dữ liệu & Phân tích - Chuyên viên cấp 4 Phòng Phân tích & Khai thác Dữ liệu
# 40 Chuyên viên cao cấp Quản trị dữ liệu - Hà Nội - TA083
# 41 Chuyên viên/CVCC Mô hình kinh doanh (Data scientist) - Khối Dữ liệu
# 42 Chuyên viên/CVCC Mô hình kinh doanh (Data scientist) - Khối Dữ liệu
# 43 Chuyên viên cao cấp Quản trị dữ liệu - Hà Nội - TA083
# 44 Chuyên viên/CVCC Kiểm định mô hình - Khối Dữ liệu
# 45 Chuyên viên/CVCC Kiểm định mô hình - Khối Dữ liệu
# 46 [Ban Tài chính - HO HN] Trưởng phòng Quản trị dữ liệu
# 47 Chuyên viên/CVCC Công nghệ mô hình - Khối Dữ liệu
# 48 Chuyên viên/CVCC Công nghệ mô hình (AI/ML Ops) - Khối Dữ liệu
# 49 Chuyên Viên cao cấp Quản trị dữ liệu - HN - TA083
# 50 Chuyên Viên cao cấp/ Chuyên gia Quản trị dữ liệu - HN - TA083
# 51 Chuyên viên quản trị cơ sở dữ liệu, Phòng MIS, Khối Tài chính kế toán
# 52 Chuyên viên quản trị cơ sở dữ liệu, Phòng MIS, Khối Tài chính kế toán
# 53 Chuyên viên/CVCC Phân tích Khách hàng cá nhân - Khối Dữ liệu
# 54 Chuyên viên cao cấp phân tích và tích hợp dữ liệu (Intergration Engineering)
# 55 Chuyên viên cao cấp phân tích và tích hợp dữ liệu (Intergration Engineering)
# 56 Chuyên viên cao cấp phân tích và tích hợp dữ liệu (Intergration Engineering)
# 57 Chuyên viên/Chuyên viên chính phân tích dữ liệu kinh doanh (BI analytics)
# 58 HO - CV/CVCC Phân tích dữ liệu báo cáo, khối Bán lẻ (MIS)
# 59 Nhân viên phân tích dữ liệu kế hoạch - Làm việc tại AA Tây Ninh
# 60 CVCC Quản trị dữ liệu Mô hình AIML - Hà Nội - TA139
# 61 CV/CVC/CVCC Phân tích dữ liệu nhân sự - Hà Nội - TA050
# 62 Chuyên viên/CVCC Phân tích Khách hàng doanh nghiệp - Khối Dữ liệu
# 63 Nhân viên phân tích dữ liệu kế toán - Làm việc tại AA Tây Ninh
# 64 Chuyên gia Khoa học Dữ liệu Ngân hàng Số - Digital Data Science
# 65 Chuyên viên/Chuyên viên cao cấp an toàn dữ liệu (Data security)
# 66 Chuyên viên Phân tích thị trường & Cơ sở dữ liệu | Thaco Auto Miền Bắc
# 67 Chuyên viên chính/Chuyên viên cao cấp quản trị dữ liệu (Data Governance)
# 68 Chuyên viên chính/Chuyên viên cao cấp quản trị dữ liệu (Data Governance)
# 69 Khối CNTT - Chuyên Viên Ban Tích Hợp Dữ Liệu và Báo cáo
# 70 Kỹ sư Dữ liệu (Data Engineer) - Ban Dự án
# 71 Kỹ sư Dữ liệu (Data Engineer) - Ban Dự án
# 72 Chuyên gia Phân tích dữ liệu kênh Kinh doanh số
# 73 Chuyên viên Phân tích dữ liệu (Khối QTRR)
# 74 Chuyên viên Phân tích dữ liệu (Khối QTRR)
# 75 Chuyên viên Phân tích dữ liệu kinh doanh - Data Analyst
# 76 Cộng tác viên Quản lý dữ liệu - Ban Văn hóa
# 77 Chuyên viên Cao cấp Dữ liệu - Dự án Core Banking
# 78 Chuyên viên Cao cấp Dữ liệu - Dự án Core Banking
# 79 Chuyên viên Cao cấp Dữ liệu - Dự án Core Banking
# 80 Nhân Viên Kiểm Soát Dữ Liệu Kho - Warehouse Inventory Controller
# 81 [IT]  Kỹ sư Dữ liệu ( Bộ phận thiết kế Điện – Điện tử) Nam Từ Liêm, Hà Nội (15-50 triệu)
# 82 Chuyên gia Quản trị Dữ liệu - MSB DF - DXA - 1M387
# 83 CHUYÊN VIÊN ALM (Mảng Quản lý Dữ liệu và báo cáo),Phòng Quản lý Tài sản Nợ - Có (ALM) - Khối Tài chính Kế toán
# 84 Chuyên viên cao cấp Quản trị Thu hồi nợ và Phân tích dữ liệu - Khối Xử lý và Thu hồi nợ
# 85 Chuyên viên quản trị  dữ liệu và phát triển báo cáo
# 86 Chuyên viên quản trị  dữ liệu và phát triển báo cáo
# 87 DTC - Chuyên viên quy trình và chính sách quản trị dữ liệu
# 88 R&D Data Analyst – Chuyên viên dữ liệu R&D
# 89 CV/NV QUẢN TRỊ CƠ SỞ DỮ LIỆU (DBA) - KHỐI CNTT
# 90 Trưởng phòng Chiến lược và phân tích dữ liệu Ngân hàng số - Ngân hàng số
# 91 Chuyên gia/Chuyên viên cao cấp Quản trị Cơ sở dữ liệu (DBA) - Khối CNTT
# 92 Chuyên gia/Chuyên viên cao cấp Quản trị Cơ sở dữ liệu (DBA) - Khối CNTT
# 93 Nhân Viên Quản Lý Dữ Liệu Người Đỡ Đầu Trong Nước
# 94 [Hà Nội] - Chuyên viên Chiến lược và Quản trị dữ liệu rủi ro/Strategic & Risk Data Management Officer
# 95 Chuyên viên Quản trị Vận hành Cơ sở dữ liệu
# 96 Chuyên viên hành chính quản lý dữ liệu
# 97 Nhân viên Quản trị hệ thống dữ liệu
# 98 Nhân viên quản trị hệ thống dữ liệu
# 99 Nhân viên quản trị hệ thống dữ liệu
# 100 Chuyên viên quản trị Cơ sở dữ liệu - Phòng Vận hành ứng dụng - K.CNTT
# 101 Chuyên viên quản trị Cơ sở dữ liệu - Phòng Vận hành ứng dụng - K.CNTT
# 102 CVCC Vận hành Cơ sở dữ liệu  - Senior DBA - Hanoi - TA114
# 103 Tester -  Phòng Phân tích và đảm bản chất lượng - Khối Dữ Liệu
# 104 Tester -  Phòng Phân tích và đảm bản chất lượng - Khối Dữ Liệu
# 105 Chuyên viên Quản trị cơ sở dữ liệu (DBA) - Khối CNTT
# 106 Nhân Viên Nhập Dữ Liệu - Mỹ Hào, Hưng Yên - Làm 3 ca
# 107 CVCC Phân tích dữ liệu Kinh doanh - Hồ Chí Minh - TA131
# 108 Data & Inventory Supervisor/ Giám sát Dữ liệu hệ thống & Quản lý hàng tồn kho ( ICD Tân Cảng Sóng Thần)
# 109 Nhân Viên Nhập Dữ Liệu/ Data Entry Clerk (KHO 21- ICD TÂN CẢNG SÓNG THẦN - BÌNH DƯƠNG)
# 110 [HẬU GIANG] 10 KỸ THUẬT VIÊN XỬ LÝ DỮ LIỆU CA HÀNH CHÍNH (8H - 17H50)
# 111 Nhân Viên Xử Lý Dữ Liệu
# 112 Nhân viên Admin Phân tích dữ liệu
# 113 Data Analysis Intern / Thực tập sinh Phân tích Dữ liệu
# 114 Chuyên viên Thu thập dữ liệu BĐS (Thổ cư/Dự án)
# 115 Chuyên gia Nền tảng Dữ liệu Phân tích - MSB DF - DXA - 1M411
# 116 Chuyên gia Khoa học Dữ liệu - MSB DF - DXA - 1M412
# 117 Chuyên viên Quản lý thông tin Cơ sở dữ liệu về giá
# 118 Chuyên viên Quản lý thông tin Cơ sở dữ liệu về giá
# 119 IT Helpdesk
# 120 Data engineer
# 121 Data Engineer - Hà Nội - TA083
# 122 Senior Data Analyst
# 123 Data Analyst
# 124 HR Data Analyst Specialist
# 125 Middle/Senior Data Analyst
# 126 Kỹ Thuật Viên Sửa Chữa Chung
# 127 Tư Vấn Bán Hàng
# 128 Data Analyst
# 129 PHÂN TÍCH KỸ THUẬT (CHỨNG KHOÁN)_TECHNICAL ANALYSIS
# 130 Senior Data Governance Analyst - AIML Model - Hà Nội - TA139
# 131 Senior Data Governance Modeling - Hà Nội - TA139
# 132 Senior Analytics Governance Officer - Hà Nội - TA139
# 133 CV/ CVCC Phân tích kinh doanh (CVP)
# 134 ẤN ĐỘ_KỸ SƯ PE THÀNH THẠO TIẾNG TRUNG
# 135 Data Scientist Senior/Expert - Hà Nội - TA139
# 136 Data Scientist Senior/Expert - Hà Nội - TA139
# 137 Business Intelligence Executive
#                                                                 (Mới)
# 138 HO - Giám Đốc Xây Dựng Mô Hình & Định Lượng
# 139 Chuyên viên cao cấp Phòng Kiểm soát Nội bộ và Tuân thủ
# 140 Chuyên Viên Cao Cấp Phân Tích Kinh Doanh - Mảng Thu Hồi Nợ - Hà Nội - TA139
# 141 HO - Data Quality/ Data Governance Specialist
# 142 Chuyên viên phân tích và phát triển mô hình
# 143 Chuyên viên phân tích và phát triển mô hình
# 144 Chuyên viên/CVCC Quản trị rủi ro mô hình - Khối Quản trị rủi ro
# 145 Trưởng phòng BI
# 146 Văn phòng Chuyển đổi - TT Quản lý Chương trình - Chuyên gia Phòng Quản lý dự án
# 147 CV TÀI CHÍNH CHỨNG KHOÁN
#                                                                 (Mới)
# 148 Chuyên viên MIS - Phòng Hệ thống thông tin quản lý tài chính - Khối Tài chính kế toán
# 149 [Hà Nội] Trưởng nhóm Phân tích kinh doanh
# 150 [Hà Nội] Chuyên viên Business Analyst
# 151 HO - CVCC Quản lý mô hình đo lường rủi ro, Khối Quản lý rủi ro
# 152 Chuyên gia Mô hình - Ban Chiến lược
# 153 Nhân viên Digital Marketing
# 154 Chuyên viên chiến lược kinh doanh - Văn phòng QLDA
# 155 Nhân Viên Data Analyst
# 156 CHUYÊN VIÊN PHÂN TÍCH TÀI CHÍNH
# 157 IT Application Developer Staff
# 158 [HCM] NHÂN VIÊN TRIỂN KHAI (PHẦN MỀM LĨNH VỰC Y TẾ)
# 159 Chuyên viên Trải nghiệm Khách hàng
# 160 Senior Backend Developer (Java)
# 161 Cộng tác viên Phân tích kinh doanh - Hà Nội - TA139
# 162 Cộng tác viên Phân tích kinh doanh - Hà Nội - TA139
# 163 CV Quản trị rủi ro gian lận - Khối QTRR
# 164 Chuyên viên Kế toán tổng hợp
# 165 Chuyên Viên Cao Cấp Hệ Thống Thông Tin Quản Trị (MIS)
# 166 Trợ lý kinh doanh - Sale Admin
# 167 [IT] Kỹ sư Cloud ( Bộ phận thiết kế Điện – Điện tử) - Nam Từ Liêm Hà Nội (15-50 triệu)
# 168 Senior Data Engineer
# 169 Senior Data Engineer
# 170 Chuyên viên cao cấp Mô hình rủi ro
# 171 Chuyên viên cao cấp Mô hình rủi ro
# 172 Backend Web Dev (MySQL, NodeJS, MongoDB)
# 173 Chuyên Viên Cao Cấp Hệ Thống Thông Tin Quản Trị (MIS)
# 174 Chuyên Viên Cao Cấp Quản Lý Hiệu Suất - Hà Nội - TA085
# 175 [Ban Tài chính - HO HN] Chuyên viên Báo cáo quản trị
# 176 GIÁM ĐỐC QUẢN TRỊ SỐ (NGÀNH BĐS)
# 177 Lập trình viên .NET
# 178 Lập trình viên .NET
# 179 Nhân Viên Kế Toán Kho - Thời trang DEXUS
# 180 Senior Operations Executive
# 181 NHÂN VIÊN THỐNG KÊ
# 182 Nhân viên thống kê
#                                                                 (Mới)
# 183 Demand Planning Manager
# 184 Demand Planning Manager
# 185 SC Network Modelling & Simulation Analytics Senior Manager
# 186 Chuyên viên Nghiên cứu và Phát triển thuộc Ban Kế hoạch và Phát triển Kinh doanh
# 187 Sales Analyst
# 188 Chuyên Viên Hệ Thống Thông Tin Quản Trị (MIS)
# 189 Associate Software Engineer (Oracle, SQL)
# 190 Giám đốc Phòng Quản lý Danh mục Tín dụng
# 191 PRODUCT OWNER, ZALOPAY
# 192 Nhân Viên Vận Hành Callcenter An Khang (Dược)
# 193 HO - CV/CVCC Báo cáo tín dụng, Khối Quản lý rủi ro
# 194 Kế Toán Tổng Hợp
# 195 Nhân viên thống kê mỏ khai thác (Làm việc tại Tp.Hạ Long, Quảng Ninh)
#                                                                 (Mới)
# 196 Junior Developer (Java/ Python/ JavaScript/API)
# 197 Chuyên Viên Quản Lý Hạ Tầng Máy Chủ Và Mạng Viễn Thông
# 198 Chuyên Viên Quản Lý Hạ Tầng Máy Chủ Và Mạng Viễn Thông
# 199 Chuyên viên Marketing
# 200 Chuyên viên Quản lý tài sản có rủi ro
# 201 Chuyên viên Quản lý tài sản có rủi ro
# 202 Nhân viên sale admin (kinh doanh xuất khẩu)
# 203 Chuyên Gia Phân tích tài chính - BF Collection - HCM - TA083
# 204 Data Science Expert
# 205 Backend Developer Team Leader
# 206 Chuyên viên Sale Admin (hoạch địch chiến lược)
# 207 Chuyên viên Kế hoạch Kinh doanh
# 208 CVCC Rủi ro hoạt động (dịch vụ Ngân hàng số) - FCCOM - 2Z137
# 209 Kế toán ngân hàng (Bank Accountant)
# 210 HO - CVCC Chiến lược Quản lý rủi ro, Khối Quản lý rủi ro
# 211 Marketing Executive (Thu Nhập 12-15 Triệu)
# 212 CHUYÊN VIÊN ALM (Mảng Giá vốn nội bộ (FTP),Phòng Quản lý Tài sản Nợ - Có (ALM) - Khối Tài chính Kế toán
# 213 Nhân Viên Kế Toán
# 214 NHÂN VIÊN KINH DOANH (Văn phòng và căn hộ dịch vụ)
# 215 CHUYÊN VIÊN ALM (Mảng Giá vốn nội bộ (FTP),Phòng Quản lý Tài sản Nợ - Có (ALM) - Khối Tài chính Kế toán
# 216 Chuyên Viên Cao Cấp Giám Sát Rủi Ro Khách Hàng Doanh Nghiệp, Nguồn Vốn Và Ngoại Hối
# 217 Trưởng Phòng Chăm Sóc Khách Hàng
# 218 Chuyên viên Chính Phân tích kinh doanh (Thu hồi nợ) - Hà Nội - TA079
# 219 Nhân Viên Quảng Cáo (Digital Marketing/ Advertising)
# 220 Chuyên viên Kế toán tổng hợp
# 221 Digital Account Manager
# 222 Chuyên Viên Công Nghệ Thông Tin
# 223 Nhân Viên Công Nghệ Thông Tin
# 224 Chuyên Viên Chính Phân Tích Tài Chính Phân Khúc KHCN - Hồ Chí Minh - TA125
# 225 Digital Account Manager
# 226 Backend Developer - [Smarthiz - Hoàng Mai]
# 227 PERFORMANCE TRACKING MANAGEMENT
# 228 Chuyên viên Quản trị Vận hành Hệ thống - Dự án Omni Channel
# 229 Chuyên viên Quản trị Vận hành Hệ thống - Dự án Omni Channel
# 230 Chuyên viên Quản trị Vận hành Hệ thống - Dự án Omni Channel
# 231 DIGITAL MARKETING
# 232 Nhân Viên Tiền Lương /C&B
# 233 TRƯỞNG PHÒNG QC
# 234 Chuyên Viên IT (Tiếng Trung)
# 235 TRƯỞNG PHÒNG QC
# 236 NHÂN VIÊN KẾ TOÁN TỔNG HỢP
# 237 Kế Toán Tổng Hợp
# 238 Chuyên viên Cao cấp Phân tích Tài chính - Hồ Chí Minh - TA119
# 239 Chuyên viên Cao cấp Phân tích Tài chính - Hồ Chí Minh - TA119
# 240 Chuyên viên Cao cấp Phân tích Tài chính - Hồ Chí Minh - TA119
# 241 Phó Ban Quản Trang - Phụ Trách Kinh Doanh Dịch Vụ
# 242 Chuyên Viên Tài Chính
# 243 Chuyên gia Chính sách Tài sản bảo đảm - Khối Quản trị Rủi ro và Tuân thủ
# 244 Chuyên gia Trí tuệ nhân tạo Ngân hàng Số - Digital AI Specialist
# 245 Lập trình viên .NET
#                                                                 (Mới)
# 246 Chuyên viên Giám sát và Quản lý danh mục tín dụng
# 247 CVC/CVCC Phân Tích Ngành
# 248 Chuyên Gia Phân Tích Tài Chính - Hồ Chí Minh - TA119
# 249 Regional Sales Manager
# 250 Sales Assistant / Trợ Lý Bán Hàng - Ngành Sơn
#                                              (Mới)
# 251 Nhân viên mua hàng Purchasing Staff
# 252 Giám đốc Quản lý kế hoạch và hiệu quả kinh doanh - RB - MSB - 1O168
# 253 Nhân Viên Chạy Ads Lương Cứng 10 Triệu
# 254 Thanh tra viên
# 255 Nhân viên Digital Marketing Lĩnh Vực Mỹ Phẩm
# 256 Nhân Viên Chạy Ads Lương Cứng 10 Triệu
# 257 Nhân Viên Facebook Ads (Kinh Nghiệm Từ 3 - 6 Tháng) - Lương Cứng 11 Triệu
# 258 Nhân viên Digital Marketing Lĩnh Vực Mỹ Phẩm
# 259 Nhân Viên Google Ads Facebook Ads - Lương Cứng 10 - 16 Triệu + Bonus
# 260 Nhân viên Digital Marketing Lĩnh Vực Mỹ Phẩm Thu Nhập 10 - 16 Triệu
# 261 Nhân viên Marketing
# 262 Xây dựng, Quản lý server IT và hệ thống (làm việc HCM-Phú Yên)
# 263 Nhân viên Digital Marketing
# 264 Kế Toán Tổng Hợp
# 265 Kế Toán Tổng Hợp - Hai Bà Trưng, Hà Nội
# 266 Nhân viên Marketing
# 267 Chuyên viên Đánh giá An toàn bảo mật hệ thống CNTT
# 268 Chuyên viên Đánh giá An toàn bảo mật hệ thống CNTT
# 269 Solution Architect
# 270 Chuyên viên Đánh giá An toàn bảo mật hệ thống CNTT
# 271 Chuyên viên phân tích định lượng (Quantitative Researcher)
# 272 Chuyên viên Quản lý rủi ro hoạt động cấp 3 (Mảng rủi ro CNTT)
# 273 Chuyên Viên Phân Tích Kinh Doanh (Business Analyst)
# 274 Chuyên viên An toàn thông tin
# 275 Giám đốc kinh doanh tỉnh Nghệ An, Long An, Bến Tre
# 276 Chuyên viên Digital Marketing
# 277 General Accountant (English Required)
# 278 CHUYÊN VIÊN CAO CẤP BẢO MẬT THÔNG TIN ( IT SECURITY)
# 279 Kiểm toán viên Kiểm toán Công Nghệ Thông Tin
# 280 [HCM] TRIỂN KHAI PHẦN MỀM (Level: CTV)
# 281 Chuyên viên Kỹ thuật Gỗ
# 282 NHÂN VIÊN SEO MARKETING
# 283 Chuyên viên cao cấp Phòng chống gian lận
# 284 Kế toán tổng hợp
# 285 Chuyên Gia Tài chính Quản trị - Hà Nội - TA119
# 286 Chuyên Gia Tài chính Quản trị - Hà Nội - TA119
# 287 Chuyên Viên Cao Cấp Phân Tích Tài Chính Phân Khúc KHCN - Hồ Chí Minh - TA125
# 288 Văn phòng Chuyển đổi - TT Quản lý Chương trình - Chuyên viên cao cấp Phòng đảm bảo chất lượng
# 289 Management Trainee for Business Analyst
# 290 Trưởng phòng/ Trưởng nhóm  mua hàng phụ kiện đồ da
# 291 [HO HN] Chuyên viên cao cấp Quản lý Ứng dụng Core Banking (Omni) - Khối CNNH
# 292 Văn phòng Chuyển đổi - TT Quản lý Chương trình - Chuyên viên cấp 3 Phòng NC&PT nền tảng
# 293 Trưởng Phòng/phó phòng Bán Hàng
# 294 Digital Maketing Manager
# 295 Kỹ sư hệ thống (System Engineer)
# 296 Chuyên Viên Phân Tích Định Lượng (Quantitative Researcher)
# 297 Chuyên Viên Cao Cấp Tài Chính Quản Trị
# 298 Chuyên Viên Chính Quản Lý Hiệu Suất - Hà Nội - TA085
# 299 Chuyên Viên Chính Quản Lý Chất Lượng - Khối Vận Hành - Hà Nội - TA085
# 300 GIÁM SÁT KÊNH PHÂN PHỐI SẢN PHẨM QUẢN LÝ TÀI SẢN
# 301 Flutter Developer - [Smarthiz - Hoàng Mai]
# 302 Trưởng phòng Marketing
# 303 Project Supervisor (Investment product)
# 304 Chuyên Viên Maketing
# 305 Quản Lý Khu Vực Miền Tây (GSM)
# 306 ẤN ĐỘ_KỸ SƯ PE THÀNH THẠO TIẾNG TRUNG
# 307 Nhân Viên Facebook ADS 6 Tháng Kinh Nghiệm Lương Cứng 10Tr
# 308 Nhân Viên Chạy Quảng Cáo Facebook 6 Tháng Kinh Nghiệm
# 309 Nhân viên Digital Marketing Lĩnh Vực Mỹ Phẩm
# 310 Nhân Viên Facebook ADS (Kinh Nghiệm 6 Tháng) - Lương Cứng 8-10 Triệu
# 311 Nhân Viên Digital Marketing (Kinh Nghiệm 6 Tháng) - Lương Cứng 8-10 Triệu
# 312 TRƯỞNG PHÒNG BÁN HÀNG DỊCH VỤ MAZDA
# 313 Kế Toán Tổng Hợp
# 314 [Ban Tài chính - HO HN] CVCC/CG Đối tác Phân tích kinh doanh
# 315 Nhân Viên Thống Kê Sản Xuất
# 316 Nhân viên PR
# 317 Mobile Android Developer
# 318 Digital Account Executive
# 319 Giám Đốc Kinh Doanh Tỉnh
# 320 Senior Java Developer (T24 Corebanking)
# 321 KHỐI CNTT&NHĐT - Middle-Senior Backend Developer (Python/ Java)
# 322 HO - Kiểm toán viên
# 323 HO - Kiểm toán viên CNTT
# 324 Nhân Viên Tư Vấn/ Telesales -Giáo Dục Cấp Cao (Lương Cứng 7-12 Triệu/ Thu Nhập Upto 30 Triệu)
# 325 Senior Data Engineer
# 326 Chuyên viên/CVCC Kiểm định Mô hình rủi ro - Khối Quản trị rủi ro
# 327 Senior PHP engineer (leader)
# 328 [PHENIKAA UNI] Nhân viên phát triển chương trình Ngoại ngữ
# 329 [HO HN] Chuyên viên cao cấp Quản lý Ứng dụng ngoài Core banking (Thẻ) - Khối CNNH
# 330 Chuyên viên cao cấp Quản trị Nhân tài - Hà Nội - TA133
# 331 Dropshipping Product Ideas
# 332 TikTok Marketing
# 333 IT System Administrator
# 334 Senior Developer
# 335 Chuyên Viên Báo Cáo Quản Trị (Kế Toán Quản Trị - FP&A)
# 336 Nhân Viên Kho ( Nguyên Khê- Đông Anh)
# 337 Thực Tập Sinh Công Nghệ Thông Tin – IT Intern
# 338 NHÂN VIÊN THIẾT KẾ CAD
# 339 Senior HRBP Specialist (For sales, FMCG)
# 340 CHUYÊN VIÊN / CHUYÊN VIÊN CAO CẤP MÔ HÌNH QUẢN LÝ RỦI RO - HỘI SỞ HCM
# 341 Kỹ sư cầu nối BrSE (PHP) - Tiếng nhật N2
# 342 [VĨNH PHÚC] GIÁM SÁT SẢN XUẤT BÁNH MÌ (Thu nhập up to 25tr)
# 343 Kỹ sư cầu nối BrSE (Java,Python etc.) - Tiếng nhật N2
# 344 Chuyên viên cao cấp - Chính sách bán lẻ
# 345 Chuyên viên chính sách và giám sát tài sản đảm bảo, Trung tâm định giá, khối tái thẩm và phê duyệt
# 346 Learning & Development Specialist
# 347 Chuyên Viên Cao Cấp Chính Sách Rủi Ro
# 348 Nhân viên Hành chính
# 349 Trưởng Phòng Hệ Thống Thông Tin Quản Trị (MIS)
# 350 Chuyên gia Quản trị Nhân tài
# 351 Trưởng bộ phận Kế hoạch sản xuất (Ngành may mặc)
# 352 Chuyên gia Quản trị Nhân tài
# 353 TRƯỞNG PHÒNG NHÂN SỰ | THACO AUTO BMW TPHCM; HÀ NỘI
# 354 Senior Data Engineer
# 355 Chuyên gia/Chuyên viên cao cấp an ninh thông tin (Pentest)
# 356 CHUYÊN VIÊN CHÍNH PHÂN TÍCH NGHIỆP VỤ (BUSINESS ANALYST)
# 357 Khối GSKD&XLN - Phòng Xử lý nợ phía Bắc- Chuyên viên Ban Cơ cấu nợ
# 358 Chuyên Viên Phát Triển Sản Phẩm Tiền & Trái Phiếu
# 359 Kỹ sư thiết kế cơ khí
# 360 HO - Kiểm toán viên cao cấp
# 361 Trưởng nhóm Marketing
# 362 CV/CVC/CVCC Xây dựng Mô hình rủi ro tín dụng - QLRR - MSB - 1P336
# 363 Giám đốc kinh doanh Tỉnh (Ứng dụng số TINCard)
# 364 PHÓ PHÒNG KẾ TOÁN {QUẬN 7}
# 365 Chuyên Viên Cao Cấp Chính Sách IFRS - Hà Nội - TA119
# 366 Kế Toán Tổng Hợp
# 367 Chuyên Viên Kế Hoạch Tổng Hợp
# 368 Quản lý nhóm - Kế hoạch chính sách bán lẻ
# 369 Chuyên Viên Kế Hoạch Tổng Hợp
# 370 Trưởng phòng Tài chính Quản trị Hoạt động Thu hồi nợ - Hồ Chí Minh - TA119
# 371 NV/CV/CVC/CVCC Bán Hàng Qua Điện Thoại - Miền Nam
# 372 Nhân Viên Kiểm Thử Phần Mềm
# 373 [HCM] Kĩ thuật viên bộ phận thiết bị lạnh
# 374 Nhân Viên Vận Hành - Cơ Khí - Hà Nội
# 375 Chuyên viên R&D Marketing
# 376 North Sales Manager
# 377 South Sales Manager
# 378 Chuyên viên phân tích tài chính, đầu tư / IR
# 379 Bioinformatician
# 380 Chuyên viên Digital Marketing
# 381 Giám Sát Bán Hàng - Bạc Liêu
# 382 Thực tập sinh Bộ phận Chuỗi cung ứng (Đóng gói, Pha chế, Chất lượng, Kỹ thuật)
# 383 Hà Nội - Nhân Viên Bán Hàng Kênh Sỉ
# 384 [HCM] Nhân viên bán hàng kênh sỉ (Hợp đồng 8 tháng)
# 385 Hà Nội - Giám Sát Bán Hàng
# 386 [Vĩnh Long] Giám sát bán hàng
# 387 [Kiên Giang] Giám sát bán hàng
# 388 Kiên Giang - Nhân Viên Bán Hàng Kênh Đại Lý
# 389 [Hà Nội] Nhân Viên Vận Hành Máy Sản Xuất - Ca 8 Tiếng
# 390 [Thường Tín - Hà Nội] Nhân Viên Kiểm Hàng - Warehouse Checker (làm việc 3 ca)
# 391 CV/ CVCC Quản trị Nhân sự - Ban Dự án
# 392 Nhân viên Hỗ trợ bán hàng (Sale Admin)
# 393 [Unilever - Quận 7 HCM] Channel Activation Assistant for Manager
# 394 Nhân viên Kế toán
#                                                                 (Mới)
# 395 Database Administrator
# 396 Data Analyst/ Workforce Management Analyst
# 397 Senior Data Analyst, OTA
# 398 Data Analyst Executive
# 399 GAME DESIGNER - LẬP KẾ HOẠCH CHO GAME
# 400 GAME DESIGNER - LẬP KẾ HOẠCH CHO GAME
# 401 GAME DESIGNER - LẬP KẾ HOẠCH CHO GAME
# 402 GAME DESIGNER - LẬP KẾ HOẠCH CHO GAME
# 403 Marketing Manager
# 404 GAME DESIGNER - LẬP KẾ HOẠCH CHO GAME
# 405 GAME DESIGNER - LẬP KẾ HOẠCH CHO GAME
# 406 Công nhân nhà kho
# 407 GAME DESIGNER - LẬP KẾ HOẠCH CHO GAME
# 408 GAME DESIGNER - LẬP KẾ HOẠCH CHO GAME
# 409 Digital Marketing Exceutive ( Mảng Beauty)
# 410 Nhân Viên Nhập Liệu (Hà Nội)
# 411 Nhân Viên Nhập Liệu (Hà Nội)
# 412 Chuyên gia Bảo mật công nghệ thông tin/ IT Security Expert - HN&HCM
# 413 [Đà Lạt] Nhân Viên Bán Hàng Kênh Khách Hàng Trọng Điểm
# 414 Nhân Viên Bán Hàng Kênh Khách Hàng Trọng Điểm​ - Đồng Nai
# 415 [Bến Tre] Nhân Viên Bán Hàng Kênh Đại Lý
# 416 Fresher Python Developer
# 417 Fresher .Net Developer
# 418 Quản lý sản xuất
# 419 Digital Marketing
# 420 Chuyên viên quản lý chất lượng
# 421 Senior Merchandising Specialist
# 422 (Chuyên Viên Quản Lý Danh Mục Rủi Ro) Risk Porfolio Specialist
# 423 TRƯỞNG BỘ PHẬN KẾ HOẠCH -CHIẾN LƯỢC KINH DOANH
#                                                                 (Mới)
# 424 NHÂN VIÊN HỆ THỐNG ỨNG DỤNG
#                                                                 (Mới)
# 425 Senior Java Developer
# 426 Kỹ Thuật Viên Phòng Xét Nghiệm Vi Sinh Thu Nhỏ tại Khoa xét nghiệm Hạ Hòa – Phú Thọ (JDHAN_1123_013)
# 427 Chuyên Viên Quan Hệ Khách Hàng Cá Nhân (Tiền Giang)
# 428 Chuyên viên phân tích và quản trị dịch vụ tài chính - K.CNTT
# 429 Nhân Viên Tiktok Ads
# 430 Chuyên viên IT (Phần mềm)
# 431 Nhân viên điều phối hàng hóa (ngành thời trang)
# 432 kế toán kinh doanh
# 433 Nhân viên Thiết Kế 2D
# 434 Chuyên viên phân tích và quản trị dịch vụ tài chính - K.CNTT
# 435 Kế Toán Trưởng (Xây Dựng)
# 436 Chuyên Viên Báo Cáo Quản Trị (Logistics)
# 437 Nhân Viên Triển Khai Dự Án
# 438 NHÂN VIÊN KẾ HOẠCH SẢN XUẤT - NHÀ MÁY BÌNH DƯƠNG
# 439 Nhân Viên Kinh Doanh
# 440 [KCN Thăng Long, Hà Nội, có xe đưa đón] Kỹ sư sản xuất (10M - 13M) (23442)
# 441 Chuyên Viên Quan Hệ Khách Hàng Cá Nhân (Cần Thơ)
# 442 HÀNH CHÍNH TIẾNG NHẬT N2 TẠI KCN THĂNG LONG II - HƯNG YÊN, KHÔNG YC KINH NGHIỆM
# 443 NHÂN VIÊN DIGITAL MARKETING
# 444 Chuyên viên Cao cấp Chính sách Thu hồi nợ
# 445 Chuyên viên phân tích và quản trị dịch vụ tài chính - K.CNTT
# 446 Kỹ sư phần mềm [upto 25tr] Từ Liêm, HN.
# 447 CVC/CVCC chiến lược thu hồi nợ - Hồ Chí Minh - TA146
# 448 Senior Business Analyst
# 449 ẤN ĐỘ_TRƯỞNG PHÒNG KỸ THUẬT SẢN XUẤT THÀNH THẠO TIẾNG TRUNG
# 450 Giám đốc sản xuất
# 451 Nhân viên thống kê
# 452 Nhân Viên Thống Kê ( Nhà Máy )
# 453 Nhan viên thống kê kỹ thuật
# 454 Khối Công nghệ thông tin - Chuyên Viên Ban phát triển giải pháp
# 455 Chuyên viên Chính sách và sản phẩm tín dụng KHCN  (Dự án RLOS)
# 456 CHUYÊN VIÊN NHÂN SỰ TIỀN LƯƠNG
# 457 Program Analyst Senior Executive (Database Developer)
# 458 Chuyên Viên Nghiên Cứu Và Phát Triển
# 459 Junior PHP Developer
# 460 Chuyên Viên Hành Chính
# 461 Nhân Viên Tiktok Ads ( Thu nhập 15-20 tr )
# 462 Kế toán tổng hợp
# 463 Chuyên mua Kế hoạch mua hàng
# 464 Senior Backend Developer (Java – Spring boot)
# 465 Chuyên viên Cao cấp Phân tích Chiến lược Thu hồi Nợ
# 466 IT Phần mềm (15M, Bắc Ninh)
# 467 Chuyên Viên Giám Sát Chất Lượng (Thời vụ 6 tháng)
# 468 Chuyên viên Marketing
# 469 Nhân viên IT
# 470 Chuyên Viên Chạy Ads ( Quảng cáo)
# 471 Phó Quản Đốc Xưởng Sản Xuất (Quản lý Sản Xuất)
# 472 [PHENIKAA GROUP] CHUYÊN VIÊN TÀI CHÍNH - KẾ HOẠCH
# 473 Trưởng Phòng/Trưởng Nhóm Kinh Doanh (Thẩm Mỹ)
# 474 Chuyên viên / Chuyên viên Cao cấp Quản lý Rủi ro Hoạt động - Hội sở HCM
# 475 Nhân viên Marketing
# 476 Chuyên viên Cao cấp Báo cáo Thống kê - Khối Tài chính Kế hoạch - Hội sở HDBank (HCM)
# 477 Quản lý chất lượng (QA/QC)
# 478 Chuyên viên cao cấp quản lý Danh mục tín dụng
# 479 KẾ TOÁN KINH DOANH (HÒA MỸ PHÚ YÊN)
# 480 Chuyên Viên Khách Hàng Cá Nhân Khu Vực Tp.Hồ Chí Minh
# 481 Nhân Viên Tiktok Ads ( Số lượng 1 ứng viên)
# 482 Nhân viên Marketing
# 483 Chuyên viên Ngành hàng
# 484 KẾ TOÁN KINH DOANH (LÀM PHÚ YÊN)
# 485 kiểm soát nội bộ (Thanh Hóa/HCM)
# 486 [PHENIKAA GROUP] CHUYÊN VIÊN TÀI CHÍNH DOANH NGHIỆP
# 487 VIDEO EDITOR
# 488 Chuyên viên Hỗ trợ tín dụng lưu động - Khối Vận hành
# 489 Kế Toán Tổng Hợp - Quận Đống Đa
# 490 IT - Automation Tester (Mobile)
# 491 Parts Marketing Specialist
# 492 NHÂN VIÊN THỐNG KÊ KHO
# 493 Chuyên viên cao cấp - Kế Hoạch Hàng Hóa (Merchandiser)
# 494 Chuyên Viên Quản Trị Hệ Thống Phần Mềm Lĩnh Vực Y Tế
# 495 Brand Manager
# 496 NHÂN VIÊN KẾ TOÁN
# 497 Lập trình viên Full Stack - Hà Nội
# 498 Kỹ thuật viên xét nghiệm
# 499 Chuyên viên cao cấp - Kế Hoạch Hàng Hóa (Merchandiser)

# %%
# Scraping & parsing data from the job_links
df_job_link = extract_job_links(
    df_search_page=df_search_page[:200], # all the jobs after the 4th page does not seem relevant to the keyword anymore. 
    load_sleep_time=8,
    scroll_sleep_time=1
)
# Out:
# 1 / 200 jobs scraped
# 2 / 200 jobs scraped
# 3 / 200 jobs scraped
# 4 / 200 jobs scraped
# 5 / 200 jobs scraped
# 6 / 200 jobs scraped
# 7 / 200 jobs scraped
# 8 / 200 jobs scraped
# 9 / 200 jobs scraped
# 10 / 200 jobs scraped
# 11 / 200 jobs scraped
# 12 / 200 jobs scraped
# 13 / 200 jobs scraped
# 14 / 200 jobs scraped
# 15 / 200 jobs scraped
# 16 / 200 jobs scraped
# 17 / 200 jobs scraped
# 18 / 200 jobs scraped
# 19 / 200 jobs scraped
# 20 / 200 jobs scraped
# 21 / 200 jobs scraped
# 22 / 200 jobs scraped
# 23 / 200 jobs scraped
# 24 / 200 jobs scraped
# 25 / 200 jobs scraped
# 26 / 200 jobs scraped
# 27 / 200 jobs scraped
# 28 / 200 jobs scraped
# 29 / 200 jobs scraped
# 30 / 200 jobs scraped
# 31 / 200 jobs scraped
# First attempt failed for https://careerbuilder.vn/vi/tim-viec-lam/chuyen-vien-cao-cap-phan-tich-du-lieu-rui-ro.35BDF418.html: Message: unknown error: net::ERR_INTERNET_DISCONNECTED
#   (Session info: headless chrome=119.0.6045.200)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7840C82B2+55298]
# 	(No symbol) [0x00007FF784035E02]
# 	(No symbol) [0x00007FF783EF05AB]
# 	(No symbol) [0x00007FF783EEC353]
# 	(No symbol) [0x00007FF783EDF4CC]
# 	(No symbol) [0x00007FF783EE0714]
# 	(No symbol) [0x00007FF783EDF8DF]
# 	(No symbol) [0x00007FF783EDE803]
# 	(No symbol) [0x00007FF783EDE7A8]
# 	(No symbol) [0x00007FF783EDCF0E]
# 	(No symbol) [0x00007FF783EDD803]
# 	(No symbol) [0x00007FF783EF29BF]
# 	(No symbol) [0x00007FF783F6AE27]
# 	(No symbol) [0x00007FF783F520AA]
# 	(No symbol) [0x00007FF783F6AAA4]
# 	(No symbol) [0x00007FF783F51E83]
# 	(No symbol) [0x00007FF783F2670A]
# 	(No symbol) [0x00007FF783F27964]
# 	GetHandleVerifier [0x00007FF784440AAB+3694587]
# 	GetHandleVerifier [0x00007FF78449728E+4048862]
# 	GetHandleVerifier [0x00007FF78448F173+4015811]
# 	GetHandleVerifier [0x00007FF7841647D6+695590]
# 	(No symbol) [0x00007FF784040CE8]
# 	(No symbol) [0x00007FF78403CF34]
# 	(No symbol) [0x00007FF78403D062]
# 	(No symbol) [0x00007FF78402D3A3]
# 	BaseThreadInitThunk [0x00007FFD8F44257D+29]
# 	RtlUserThreadStart [0x00007FFD912CAA58+40]
#
# Second attempt succeed
# 32 / 200 jobs scraped
# 33 / 200 jobs scraped
# 34 / 200 jobs scraped
# 35 / 200 jobs scraped
# 36 / 200 jobs scraped
# 37 / 200 jobs scraped
# 38 / 200 jobs scraped
# 39 / 200 jobs scraped
# 40 / 200 jobs scraped
# 41 / 200 jobs scraped
# 42 / 200 jobs scraped
# 43 / 200 jobs scraped
# 44 / 200 jobs scraped
# 45 / 200 jobs scraped
# 46 / 200 jobs scraped
# 47 / 200 jobs scraped
# 48 / 200 jobs scraped
# 49 / 200 jobs scraped
# 50 / 200 jobs scraped
# 51 / 200 jobs scraped
# 52 / 200 jobs scraped
# 53 / 200 jobs scraped
# 54 / 200 jobs scraped
# 55 / 200 jobs scraped
# 56 / 200 jobs scraped
# 57 / 200 jobs scraped
# 58 / 200 jobs scraped
# 59 / 200 jobs scraped
# 60 / 200 jobs scraped
# 61 / 200 jobs scraped
# 62 / 200 jobs scraped
# 63 / 200 jobs scraped
# 64 / 200 jobs scraped
# 65 / 200 jobs scraped
# 66 / 200 jobs scraped
# 67 / 200 jobs scraped
# 68 / 200 jobs scraped
# 69 / 200 jobs scraped
# 70 / 200 jobs scraped
# 71 / 200 jobs scraped
# 72 / 200 jobs scraped
# 73 / 200 jobs scraped
# 74 / 200 jobs scraped
# 75 / 200 jobs scraped
# 76 / 200 jobs scraped
# 77 / 200 jobs scraped
# 78 / 200 jobs scraped
# 79 / 200 jobs scraped
# 80 / 200 jobs scraped
# 81 / 200 jobs scraped
# 82 / 200 jobs scraped
# 83 / 200 jobs scraped
# 84 / 200 jobs scraped
# 85 / 200 jobs scraped
# 86 / 200 jobs scraped
# 87 / 200 jobs scraped
# 88 / 200 jobs scraped
# 89 / 200 jobs scraped
# 90 / 200 jobs scraped
# First attempt failed for https://careerbuilder.vn/vi/tim-viec-lam/cv-nv-quan-tri-co-so-du-lieu-dba-khoi-cntt.35BEF9EE.html: 'NoneType' object has no attribute 'find'
# Second attempt succeed
# 91 / 200 jobs scraped
# 92 / 200 jobs scraped
# 93 / 200 jobs scraped
# 94 / 200 jobs scraped
# 95 / 200 jobs scraped
# 96 / 200 jobs scraped
# 97 / 200 jobs scraped
# 98 / 200 jobs scraped
# 99 / 200 jobs scraped
# 100 / 200 jobs scraped
# 101 / 200 jobs scraped
# 102 / 200 jobs scraped
# 103 / 200 jobs scraped
# 104 / 200 jobs scraped
# 105 / 200 jobs scraped
# 106 / 200 jobs scraped
# 107 / 200 jobs scraped
# 108 / 200 jobs scraped
# 109 / 200 jobs scraped
# 110 / 200 jobs scraped
# 111 / 200 jobs scraped
# 112 / 200 jobs scraped
# 113 / 200 jobs scraped
# 114 / 200 jobs scraped
# 115 / 200 jobs scraped
# 116 / 200 jobs scraped
# 117 / 200 jobs scraped
# 118 / 200 jobs scraped
# 119 / 200 jobs scraped
# 120 / 200 jobs scraped
# 121 / 200 jobs scraped
# 122 / 200 jobs scraped
# 123 / 200 jobs scraped
# 124 / 200 jobs scraped
# 125 / 200 jobs scraped
# First attempt failed for https://careerbuilder.vn/vi/tim-viec-lam/hr-data-analyst-specialist.35BEE606.html: 'NoneType' object has no attribute 'find'
# Second attempt succeed
# 126 / 200 jobs scraped
# 127 / 200 jobs scraped
# 128 / 200 jobs scraped
# 129 / 200 jobs scraped
# 130 / 200 jobs scraped
# 131 / 200 jobs scraped
# 132 / 200 jobs scraped
# 133 / 200 jobs scraped
# 134 / 200 jobs scraped
# 135 / 200 jobs scraped
# 136 / 200 jobs scraped
# 137 / 200 jobs scraped
# 138 / 200 jobs scraped
# 139 / 200 jobs scraped
# First attempt failed for https://careerbuilder.vn/vi/tim-viec-lam/ho-giam-doc-xay-dung-mo-hinh-dinh-luong.35BE153E.html: 'NoneType' object has no attribute 'find'
# Second attempt succeed
# 140 / 200 jobs scraped
# 141 / 200 jobs scraped
# 142 / 200 jobs scraped
# 143 / 200 jobs scraped
# 144 / 200 jobs scraped
# 145 / 200 jobs scraped
# 146 / 200 jobs scraped
# 147 / 200 jobs scraped
# 148 / 200 jobs scraped
# 149 / 200 jobs scraped
# 150 / 200 jobs scraped
# 151 / 200 jobs scraped
# 152 / 200 jobs scraped
# 153 / 200 jobs scraped
# 154 / 200 jobs scraped
# 155 / 200 jobs scraped
# 156 / 200 jobs scraped
# 157 / 200 jobs scraped
# 158 / 200 jobs scraped
# 159 / 200 jobs scraped
# 160 / 200 jobs scraped
# 161 / 200 jobs scraped
# 162 / 200 jobs scraped
# 163 / 200 jobs scraped
# 164 / 200 jobs scraped
# 165 / 200 jobs scraped
# 166 / 200 jobs scraped
# 167 / 200 jobs scraped
# First attempt failed for https://careerbuilder.vn/vi/tim-viec-lam/tro-ly-kinh-doanh-sale-admin.35BEFDBC.html: 'NoneType' object has no attribute 'find_all'
# Second attempt succeed
# 168 / 200 jobs scraped
# 169 / 200 jobs scraped
# 170 / 200 jobs scraped
# 171 / 200 jobs scraped
# 172 / 200 jobs scraped
# 173 / 200 jobs scraped
# 174 / 200 jobs scraped
# 175 / 200 jobs scraped
# 176 / 200 jobs scraped
# 177 / 200 jobs scraped
# 178 / 200 jobs scraped
# 179 / 200 jobs scraped
# 180 / 200 jobs scraped
# 181 / 200 jobs scraped
# 182 / 200 jobs scraped
# 183 / 200 jobs scraped
# First attempt failed for https://careerbuilder.vn/vi/tim-viec-lam/nhan-vien-thong-ke.35BF19F1.html: 'NoneType' object has no attribute 'find'
# Second attempt succeed
# 184 / 200 jobs scraped
# 185 / 200 jobs scraped
# 186 / 200 jobs scraped
# 187 / 200 jobs scraped
# 188 / 200 jobs scraped
# 189 / 200 jobs scraped
# 190 / 200 jobs scraped
# 191 / 200 jobs scraped
# 192 / 200 jobs scraped
# 193 / 200 jobs scraped
# 194 / 200 jobs scraped
# 195 / 200 jobs scraped
# 196 / 200 jobs scraped
# 197 / 200 jobs scraped
# 198 / 200 jobs scraped
# 199 / 200 jobs scraped
# 200 / 200 jobs scraped
# success 200 out of 200 jobs        (100.0%)
# failed 0 out of 200 jobs        (0.0%)
# Failed Indices: {}

# %%
# Drop unnecessaies, merging df_search_page & df_job_link
df_search_page.drop(['welfare', 'salary'], axis=1, inplace=True)
df_job_link.drop(['location', 'update_date', 'expire_date'], axis=1, inplace=True)

final_df = merge_search_page_n_job_link(
    df_search_page=df_search_page,
    df_job_link=df_job_link
)

# %%
final_df
# Out:
#                                               job_link  \
# 0    https://careerbuilder.vn/vi/tim-viec-lam/kien-...
# 1    https://careerbuilder.vn/vi/tim-viec-lam/kien-...
# 2    https://careerbuilder.vn/vi/tim-viec-lam/data-...
# 3    https://careerbuilder.vn/vi/tim-viec-lam/busin...
# 4    https://careerbuilder.vn/vi/tim-viec-lam/busin...
# ..                                                 ...
# 195  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 196  https://careerbuilder.vn/vi/tim-viec-lam/junio...
# 197  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 198  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 199  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
#
#                                              job_title  \
# 0                                    Kiến trúc Dữ liệu
# 1                                    Kiến trúc Dữ liệu
# 2                         Data Engineer - Khối Dữ liệu
# 3                      Business Analyst - Khối Dữ Liệu
# 4                      Business Analyst - Khối Dữ Liệu
# ..                                                 ...
# 195  Nhân viên thống kê mỏ khai thác (Làm việc tại ...
# 196    Junior Developer (Java/ Python/ JavaScript/API)
# 197  Chuyên Viên Quản Lý Hạ Tầng Máy Chủ Và Mạng Vi...
# 198  Chuyên Viên Quản Lý Hạ Tầng Máy Chủ Và Mạng Vi...
# 199                              Chuyên viên Marketing
#
#                                    comp_name    location  \
# 0    Ngân Hàng TMCP Sài Gòn - Hà Nội ( SHB )      Hà Nội
# 1    Ngân Hàng TMCP Sài Gòn - Hà Nội ( SHB )      Hà Nội
# 2                    Ngân Hàng TMCP Quân Đội      Hà Nội
# 3                    Ngân Hàng TMCP Quân Đội      Hà Nội
# 4                    Ngân Hàng TMCP Quân Đội      Hà Nội
# ..                                       ...         ...
# 195           CÔNG TY CỔ PHẦN ĐẦU TƯ BẢO LAI  Quảng Ninh
# 196                     CÔNG TY TNHH GIMASYS      Hà Nội
# 197                   TẬP ĐOÀN Y TẾ VIỆT NGA      Hà Nội
# 198                   TẬP ĐOÀN Y TẾ VIỆT NGA      Hà Nội
# 199        Công ty TNHH Thương mại Sơn Dương      Hà Nội
#
#                            expire_date   update_date  \
# 0                  Hạn nộp: 26-12-2023  [27-11-2023]
# 1                  Hạn nộp: 24-12-2023  [25-11-2023]
# 2                  Hạn nộp: 31-12-2023  [01-12-2023]
# 3     Cơ hội ứng tuyển chỉ còn: 3 ngày  [07-11-2023]
# 4                  Hạn nộp: 10-12-2023  [11-11-2023]
# ..                                 ...           ...
# 195                Hạn nộp: 20-12-2023  [01-12-2023]
# 196  Cơ hội ứng tuyển chỉ còn: Hôm nay  [04-11-2023]
# 197                Hạn nộp: 13-12-2023  [14-11-2023]
# 198                Hạn nộp: 31-12-2023  [30-11-2023]
# 199                Hạn nộp: 25-12-2023  [26-11-2023]
#
#                                               industry            staff_type  \
# 0             CNTT - Phần mềm, CNTT - Phần cứng / Mạng  Nhân viên chính thức
# 1             CNTT - Phần mềm, CNTT - Phần cứng / Mạng  Nhân viên chính thức
# 2                           CNTT - Phần mềm, Ngân hàng  Nhân viên chính thức
# 3    CNTT - Phần mềm, Ngân hàng, Quản lý chất lượng...  Nhân viên chính thức
# 4    CNTT - Phần mềm, Ngân hàng, Quản lý chất lượng...  Nhân viên chính thức
# ..                                                 ...                   ...
# 195  Vận chuyển / Giao nhận /Kho vận, Kế toán / Kiể...  Nhân viên chính thức
# 196                                    CNTT - Phần mềm  Nhân viên chính thức
# 197  CNTT - Phần mềm, CNTT - Phần cứng / Mạng, Bưu ...  Nhân viên chính thức
# 198  CNTT - Phần mềm, CNTT - Phần cứng / Mạng, Bưu ...  Nhân viên chính thức
# 199  Tiếp thị / Marketing, Hành chính / Thư ký, Quả...  Nhân viên chính thức
#
#                 salary        exp               job_level
# 0           Cạnh tranh  Trên4 Năm               Nhân viên
# 1           Cạnh tranh  Trên4 Năm               Nhân viên
# 2           Cạnh tranh  Trên1 Năm               Nhân viên
# 3           Cạnh tranh  1 - 5 Năm               Nhân viên
# 4           Cạnh tranh  1 - 5 Năm               Nhân viên
# ..                 ...        ...                     ...
# 195   8 Tr - 10 Tr VND  1 - 3 Năm               Nhân viên
# 196         Cạnh tranh  1 - 2 Năm               Nhân viên
# 197  15 Tr - 25 Tr VND  Trên3 Năm               Nhân viên
# 198         Cạnh tranh  Trên3 Năm               Nhân viên
# 199  20 Tr - 30 Tr VND  3 - 5 Năm  Trưởng nhóm / Giám sát
#
# [200 rows x 11 columns]

# %%
# Saving
final_df.to_csv('D:\WORK\Data Analysis\Raw data\data-jobs\20231203-data-jobs.csv', index=False, encoding="utf-16")

# %%
df_test = pd.read_csv('D:\WORK\Data Analysis\Raw data\data-jobs\20231203-data-jobs.csv',encoding="utf-16")
df_test
# Out:
#                                               job_link  \
# 0    https://careerbuilder.vn/vi/tim-viec-lam/kien-...
# 1    https://careerbuilder.vn/vi/tim-viec-lam/kien-...
# 2    https://careerbuilder.vn/vi/tim-viec-lam/data-...
# 3    https://careerbuilder.vn/vi/tim-viec-lam/busin...
# 4    https://careerbuilder.vn/vi/tim-viec-lam/busin...
# ..                                                 ...
# 195  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 196  https://careerbuilder.vn/vi/tim-viec-lam/junio...
# 197  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 198  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 199  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
#
#                                              job_title  \
# 0                                    Kiến trúc Dữ liệu
# 1                                    Kiến trúc Dữ liệu
# 2                         Data Engineer - Khối Dữ liệu
# 3                      Business Analyst - Khối Dữ Liệu
# 4                      Business Analyst - Khối Dữ Liệu
# ..                                                 ...
# 195  Nhân viên thống kê mỏ khai thác (Làm việc tại ...
# 196    Junior Developer (Java/ Python/ JavaScript/API)
# 197  Chuyên Viên Quản Lý Hạ Tầng Máy Chủ Và Mạng Vi...
# 198  Chuyên Viên Quản Lý Hạ Tầng Máy Chủ Và Mạng Vi...
# 199                              Chuyên viên Marketing
#
#                                    comp_name    location  \
# 0    Ngân Hàng TMCP Sài Gòn - Hà Nội ( SHB )      Hà Nội
# 1    Ngân Hàng TMCP Sài Gòn - Hà Nội ( SHB )      Hà Nội
# 2                    Ngân Hàng TMCP Quân Đội      Hà Nội
# 3                    Ngân Hàng TMCP Quân Đội      Hà Nội
# 4                    Ngân Hàng TMCP Quân Đội      Hà Nội
# ..                                       ...         ...
# 195           CÔNG TY CỔ PHẦN ĐẦU TƯ BẢO LAI  Quảng Ninh
# 196                     CÔNG TY TNHH GIMASYS      Hà Nội
# 197                   TẬP ĐOÀN Y TẾ VIỆT NGA      Hà Nội
# 198                   TẬP ĐOÀN Y TẾ VIỆT NGA      Hà Nội
# 199        Công ty TNHH Thương mại Sơn Dương      Hà Nội
#
#                            expire_date     update_date  \
# 0                  Hạn nộp: 26-12-2023  ['27-11-2023']
# 1                  Hạn nộp: 24-12-2023  ['25-11-2023']
# 2                  Hạn nộp: 31-12-2023  ['01-12-2023']
# 3     Cơ hội ứng tuyển chỉ còn: 3 ngày  ['07-11-2023']
# 4                  Hạn nộp: 10-12-2023  ['11-11-2023']
# ..                                 ...             ...
# 195                Hạn nộp: 20-12-2023  ['01-12-2023']
# 196  Cơ hội ứng tuyển chỉ còn: Hôm nay  ['04-11-2023']
# 197                Hạn nộp: 13-12-2023  ['14-11-2023']
# 198                Hạn nộp: 31-12-2023  ['30-11-2023']
# 199                Hạn nộp: 25-12-2023  ['26-11-2023']
#
#                                               industry            staff_type  \
# 0             CNTT - Phần mềm, CNTT - Phần cứng / Mạng  Nhân viên chính thức
# 1             CNTT - Phần mềm, CNTT - Phần cứng / Mạng  Nhân viên chính thức
# 2                           CNTT - Phần mềm, Ngân hàng  Nhân viên chính thức
# 3    CNTT - Phần mềm, Ngân hàng, Quản lý chất lượng...  Nhân viên chính thức
# 4    CNTT - Phần mềm, Ngân hàng, Quản lý chất lượng...  Nhân viên chính thức
# ..                                                 ...                   ...
# 195  Vận chuyển / Giao nhận /Kho vận, Kế toán / Kiể...  Nhân viên chính thức
# 196                                    CNTT - Phần mềm  Nhân viên chính thức
# 197  CNTT - Phần mềm, CNTT - Phần cứng / Mạng, Bưu ...  Nhân viên chính thức
# 198  CNTT - Phần mềm, CNTT - Phần cứng / Mạng, Bưu ...  Nhân viên chính thức
# 199  Tiếp thị / Marketing, Hành chính / Thư ký, Quả...  Nhân viên chính thức
#
#                 salary        exp               job_level
# 0           Cạnh tranh  Trên4 Năm               Nhân viên
# 1           Cạnh tranh  Trên4 Năm               Nhân viên
# 2           Cạnh tranh  Trên1 Năm               Nhân viên
# 3           Cạnh tranh  1 - 5 Năm               Nhân viên
# 4           Cạnh tranh  1 - 5 Năm               Nhân viên
# ..                 ...        ...                     ...
# 195   8 Tr - 10 Tr VND  1 - 3 Năm               Nhân viên
# 196         Cạnh tranh  1 - 2 Năm               Nhân viên
# 197  15 Tr - 25 Tr VND  Trên3 Năm               Nhân viên
# 198         Cạnh tranh  Trên3 Năm               Nhân viên
# 199  20 Tr - 30 Tr VND  3 - 5 Năm  Trưởng nhóm / Giám sát
#
# [200 rows x 11 columns]
